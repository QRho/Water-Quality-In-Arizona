# %%
import pandas as pd
import requests
import gmaps
from config import gkey

# %%
gmaps.configure(api_key=gkey)

# %%
api_url = "https://www.waterqualitydata.us/ogcservices/wfs/?request=GetFeature&service=wfs&version=2.0.0&typeNames=wqp_sites&SEARCHPARAMS=countrycode%3AUS%3Bstatecode%3AUS%3A04%3Bcountycode%3AUS%3A04%3A013%3BsiteType%3ALake%2C%20Reservoir%2C%20Impoundment%3BsampleMedia%3Awater%7CWater&outputFormat=application%2Fjson"

response = requests.get(api_url).json()

# %%
#print(response["features"][0])
coordinates = []
for feature in response["features"]:
    latitude = feature["geometry"]["coordinates"][1]
    longitude = feature["geometry"]["coordinates"][0]
    coordinates.append(tuple((latitude, longitude)))

coordinates
# Out:
# [(33.601155, -111.71375),
#  (33.8539238, -112.2684949),
#  (33.856146, -112.2698839),
#  (33.5905183, -111.23738),
#  (33.8208333, -111.6258333),
#  (33.8525, -111.6175),
#  (33.89361, -111.6419433),
#  (33.83026, -111.6217183),
#  (33.0819233, -113.0213916),
#  (33.0819233, -113.0213916),
#  (33.8502766, -112.2641666),
#  (33.90611, -112.2419433),
#  (33.6769433, -111.15361),
#  (33.5722216, -111.515555),
#  (33.5675, -111.5358333),
#  (33.8466666, -111.6172216),
#  (33.8644433, -111.60111),
#  (33.8675, -111.6141666),
#  (33.8825, -111.610555),
#  (33.8847216, -111.6244433),
#  (33.8313883, -111.6344433),
#  (33.5713883, -111.5372216),
#  (33.57361, -111.5344433),
#  (33.5913883, -111.3419433),
#  (33.5813883, -111.2588883),
#  (33.8547216, -112.2675),
#  (33.5747216, -111.4869433),
#  (33.375, -112.1375),
#  (33.3741666, -112.1375),
#  (33.3741666, -112.135555),
#  (33.570555, -112.1183333),
#  (33.57, -112.1316666),
#  (33.5113883, -111.9069433),
#  (33.5133333, -111.9075),
#  (33.4525, -111.9475),
#  (33.453055, -111.9466666),
#  (33.3763883, -112.1352766),
#  (33.5713883, -112.1291666),
#  (33.5083333, -111.9044433),
#  (33.4502766, -111.95111),
#  (33.433055, -111.9183333),
#  (33.4333333, -111.9463883),
#  (33.82, -111.6244433),
#  (33.5527766, -111.4422216),
#  (33.57204, -111.48479),
#  (33.578055, -111.3783333),
#  (33.5574383, -111.4117383),
#  (33.5360083, -111.42425),
#  (33.57399, -111.25672),
#  (33.6672216, -111.1691666),
#  (33.62477, -111.20439),
#  (33.83385, -111.6363883),
#  (33.83385, -111.6301),
#  (33.59611, -111.2319433),
#  (33.55611, -111.4472216),
#  (33.4325, -111.933055),
#  (33.0797216, -113.0247216),
#  (33.8822216, -111.6169433),
#  (33.5902766, -111.34611),
#  (33.4752766, -112.1933333),
#  (33.47611, -112.1927766),
#  (33.4747216, -112.19361),
#  (33.5772216, -111.4927766),
#  (33.37611, -112.1363883),
#  (33.373055, -112.135555),
#  (33.5875, -111.34861),
#  (33.3735833, -112.1356933),
#  (33.6353333, -111.2061666),
#  (33.5511666, -111.4312766),
#  (33.4763883, -112.0872216),
#  (33.98686, -111.7170266),
#  (33.3741666, -111.93861),
#  (33.5592583, -111.4168683),
#  (33.363055, -111.7366666),
#  (33.4347216, -111.6669433),
#  (33.5698883, -112.1319433),
#  (33.56315, -111.48193),
#  (33.375, -112.1383333),
#  (33.3741667, -112.1363889),
#  (33.3730556, -112.1363889),
#  (33.5113889, -111.9077778),
#  (33.5133333, -111.9083333),
#  (33.5705556, -112.1191667),
#  (33.57, -112.1325),
#  (33.8502778, -112.265),
#  (33.3763583, -111.9205306),
#  (33.5913889, -111.3425),
#  (33.5961111, -111.2325),
#  (33.5813889, -111.2594444),
#  (33.5771944, -111.2638667),
#  (33.5527778, -111.4427778),
#  (33.5780556, -111.3788889),
#  (33.5875, -111.3491667),
#  (33.5372333, -111.4230111),
#  (33.5594889, -111.4014333),
#  (33.6769444, -111.1541667),
#  (33.5675, -111.5363889),
#  (33.5631958, -111.4826192),
#  (33.5561111, -111.4477778),
#  (33.5674694, -111.5235861),
#  (33.8208333, -111.6263889),
#  (33.8525, -111.6183333),
#  (33.8936111, -111.6427778),
#  (33.8924722, -111.6364722),
#  (33.8525, -111.6183333),
#  (33.5961111, -111.2325),
#  (33.5875, -111.3491667),
#  (33.5372333, -111.4230111),
#  (33.8502778, -112.265),
#  (33.5913889, -111.3425),
#  (33.3741667, -112.1363889),
#  (33.6769444, -111.1541667),
#  (33.5113889, -111.9077778),
#  (33.5722222, -111.5161111),
#  (33.4330833, -111.9191667),
#  (33.5527778, -111.4427778),
#  (33.8208333, -111.6263889),
#  (33.3764843, -111.9196013),
#  (33.5565848, -111.5104323),
#  (33.5814721, -111.2821257)]

# %%
figure_layout = {
    'width': '400px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)  # Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinates)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…
